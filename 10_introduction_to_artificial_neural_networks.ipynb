# %% [markdown]
# # Introduction t artificial neural networks

# %% [markdown]
# ### Perceptron

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
iris = load_iris()
X = iris.data[:, (2,3)] #length and width
y = (iris.target == 0).astype(np.int)

# %%
per_clf = Perceptron(random_state=42)
per_clf.fit(X,y)

y_pred = per_clf.predict([[2, 0.5]])
print(y_pred)
# Out:
# [1]
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# ### Multi-layer perceptron

# %%
import tensorflow as tf
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10,
feature_columns=feature_columns)
dnn_clf.fit(x=X_train, y=y_train, batch_size=50, steps=40000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d8952c8c32fb> in <module>()
# ----> 1 feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
#       2 dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10,
#       3 feature_columns=feature_columns)
#       4 dnn_clf.fit(x=X_train, y=y_train, batch_size=50, steps=40000)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### plain tensor flow

# %%
import tensorflow as tf
from tensorflow.contrib.layers import fully_connected
n_inputs = 28*28 # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation=="relu":
            return tf.nn.relu(z)
        else:
            return z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")

# %%
with tf.name_scope("dnn"):
    hidden1 = fully_connected(X, n_hidden1, scope="hidden1")
    hidden2 = fully_connected(hidden1, n_hidden2, scope="hidden2")
    logits = fully_connected(hidden2, n_outputs, scope="outputs",
    activation_fn=None)

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(
    labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ### Execution Phase

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# WARNING:tensorflow:From <ipython-input-23-c50d5bb4a85c>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
n_epochs = 400
batch_size = 50

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images,
        y: mnist.test.labels})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Train accuracy: 0.9 Test accuracy: 0.9048
# 1 Train accuracy: 0.86 Test accuracy: 0.9221
# 2 Train accuracy: 0.92 Test accuracy: 0.9299
# 3 Train accuracy: 0.92 Test accuracy: 0.9385
# 4 Train accuracy: 0.9 Test accuracy: 0.9406
# 5 Train accuracy: 0.94 Test accuracy: 0.9459
# 6 Train accuracy: 0.98 Test accuracy: 0.9496
# 7 Train accuracy: 0.94 Test accuracy: 0.952
# 8 Train accuracy: 0.94 Test accuracy: 0.955
# 9 Train accuracy: 1.0 Test accuracy: 0.9572
# 10 Train accuracy: 0.94 Test accuracy: 0.9583
# 11 Train accuracy: 0.94 Test accuracy: 0.9607
# 12 Train accuracy: 0.94 Test accuracy: 0.9619
# 13 Train accuracy: 1.0 Test accuracy: 0.9636
# 14 Train accuracy: 0.98 Test accuracy: 0.9665
# 15 Train accuracy: 0.98 Test accuracy: 0.9664
# 16 Train accuracy: 1.0 Test accuracy: 0.9676
# 17 Train accuracy: 1.0 Test accuracy: 0.9693
# 18 Train accuracy: 0.96 Test accuracy: 0.97
# 19 Train accuracy: 0.98 Test accuracy: 0.9696
# 20 Train accuracy: 1.0 Test accuracy: 0.9713
# 21 Train accuracy: 0.98 Test accuracy: 0.9724
# 22 Train accuracy: 1.0 Test accuracy: 0.9737
# 23 Train accuracy: 1.0 Test accuracy: 0.9739
# 24 Train accuracy: 1.0 Test accuracy: 0.9733
# 249 Train accuracy: 1.0 Test accuracy: 0.9804
# 250 Train accuracy: 1.0 Test accuracy: 0.9802
# 251 Train accuracy: 1.0 Test accuracy: 0.9805
# 252 Train accuracy: 1.0 Test accuracy: 0.98
# 253 Train accuracy: 1.0 Test accuracy: 0.9804
# 254 Train accuracy: 1.0 Test accuracy: 0.9803
# 255 Train accuracy: 1.0 Test accuracy: 0.9804
# 256 Train accuracy: 1.0 Test accuracy: 0.9802
# 257 Train accuracy: 1.0 Test accuracy: 0.9803
# 258 Train accuracy: 1.0 Test accuracy: 0.9802
# 259 Train accuracy: 1.0 Test accuracy: 0.9803
# 260 Train accuracy: 1.0 Test accuracy: 0.9803
# 261 Train accuracy: 1.0 Test accuracy: 0.9804
# 262 Train accuracy: 1.0 Test accuracy: 0.9804
# 263 Train accuracy: 1.0 Test accuracy: 0.9804
# 264 Train accuracy: 1.0 Test accuracy: 0.9803
# 265 Train accuracy: 1.0 Test accuracy: 0.9805
# 266 Train accuracy: 1.0 Test accuracy: 0.9804
# 267 Train accuracy: 1.0 Test accuracy: 0.9804
# 268 Train accuracy: 1.0 Test accuracy: 0.9803
# 269 Train accuracy: 1.0 Test accuracy: 0.9803
# 270 Train accuracy: 1.0 Test accuracy: 0.9803
# 271 Train accuracy: 1.0 Test accuracy: 0.9804
# 272 Train accuracy: 1.0 Test accuracy: 0.9803
# 273 Train accuracy: 1.0 Test accuracy: 0.9805
# 274 Train accuracy: 1.0 Test accuracy: 0.9806
# 275 Train accuracy: 1.0 Test accuracy: 0.9805
# 276 Train accuracy: 1.0 Test accuracy: 0.9804
# 277 Train accuracy: 1.0 Test accuracy: 0.9804
# 278 Train accuracy: 1.0 Test accuracy: 0.9804
# 279 Train accuracy: 1.0 Test accuracy: 0.9803
# 280 Train accuracy: 1.0 Test accuracy: 0.9802
# 281 Train accuracy: 1.0 Test accuracy: 0.9804
# 282 Train accuracy: 1.0 Test accuracy: 0.9803
# 283 Train accuracy: 1.0 Test accuracy: 0.9803
# 284 Train accuracy: 1.0 Test accuracy: 0.9805
# 285 Train accuracy: 1.0 Test accuracy: 0.9805
# 286 Train accuracy: 1.0 Test accuracy: 0.9805
# 287 Train accuracy: 1.0 Test accuracy: 0.9804
# 288 Train accuracy: 1.0 Test accuracy: 0.9804
# 289 Train accuracy: 1.0 Test accuracy: 0.9804
# 290 Train accuracy: 1.0 Test accuracy: 0.9805
# 291 Train accuracy: 1.0 Test accuracy: 0.9805
# 292 Train accuracy: 1.0 Test accuracy: 0.9803
# 293 Train accuracy: 1.0 Test accuracy: 0.9805
# 294 Train accuracy: 1.0 Test accuracy: 0.9803
# 295 Train accuracy: 1.0 Test accuracy: 0.9805
# 296 Train accuracy: 1.0 Test accuracy: 0.9803
# 297 Train accuracy: 1.0 Test accuracy: 0.9805
# 298 Train accuracy: 1.0 Test accuracy: 0.9804
# 299 Train accuracy: 1.0 Test accuracy: 0.9804
# 300 Train accuracy: 1.0 Test accuracy: 0.9804
# 301 Train accuracy: 1.0 Test accuracy: 0.9805
# 302 Train accuracy: 1.0 Test accuracy: 0.9808
# 303 Train accuracy: 1.0 Test accuracy: 0.9802
# 304 Train accuracy: 1.0 Test accuracy: 0.9805
# 305 Train accuracy: 1.0 Test accuracy: 0.9805
# 306 Train accuracy: 1.0 Test accuracy: 0.9804
# 307 Train accuracy: 1.0 Test accuracy: 0.9805
# 308 Train accuracy: 1.0 Test accuracy: 0.9804
# 309 Train accuracy: 1.0 Test accuracy: 0.9801
# 310 Train accuracy: 1.0 Test accuracy: 0.9807
# 311 Train accuracy: 1.0 Test accuracy: 0.9805
# 312 Train accuracy: 1.0 Test accuracy: 0.9807
# 313 Train accuracy: 1.0 Test accuracy: 0.9805
# 314 Train accuracy: 1.0 Test accuracy: 0.9805
# 315 Train accuracy: 1.0 Test accuracy: 0.9804
# 316 Train accuracy: 1.0 Test accuracy: 0.9803
# 317 Train accuracy: 1.0 Test accuracy: 0.9805
# 318 Train accuracy: 1.0 Test accuracy: 0.9804
# 319 Train accuracy: 1.0 Test accuracy: 0.9803
# 320 Train accuracy: 1.0 Test accuracy: 0.9804
# 321 Train accuracy: 1.0 Test accuracy: 0.9807
# 322 Train accuracy: 1.0 Test accuracy: 0.9804
# 323 Train accuracy: 1.0 Test accuracy: 0.9805
# 324 Train accuracy: 1.0 Test accuracy: 0.9804
# 325 Train accuracy: 1.0 Test accuracy: 0.9805
# 326 Train accuracy: 1.0 Test accuracy: 0.9805
# 327 Train accuracy: 1.0 Test accuracy: 0.9804
# 328 Train accuracy: 1.0 Test accuracy: 0.9806
# 329 Train accuracy: 1.0 Test accuracy: 0.9806
# 330 Train accuracy: 1.0 Test accuracy: 0.9804
# 331 Train accuracy: 1.0 Test accuracy: 0.9804
# 332 Train accuracy: 1.0 Test accuracy: 0.9804
# 333 Train accuracy: 1.0 Test accuracy: 0.9804
# 334 Train accuracy: 1.0 Test accuracy: 0.9803
# 335 Train accuracy: 1.0 Test accuracy: 0.9806
# 336 Train accuracy: 1.0 Test accuracy: 0.9804
# 337 Train accuracy: 1.0 Test accuracy: 0.9805
# 338 Train accuracy: 1.0 Test accuracy: 0.9806
# 339 Train accuracy: 1.0 Test accuracy: 0.9803
# 340 Train accuracy: 1.0 Test accuracy: 0.9803
# 341 Train accuracy: 1.0 Test accuracy: 0.9803
# 342 Train accuracy: 1.0 Test accuracy: 0.9805
# 343 Train accuracy: 1.0 Test accuracy: 0.9804
# 344 Train accuracy: 1.0 Test accuracy: 0.9804
# 345 Train accuracy: 1.0 Test accuracy: 0.9804
# 346 Train accuracy: 1.0 Test accuracy: 0.9805
# 347 Train accuracy: 1.0 Test accuracy: 0.9805
# 348 Train accuracy: 1.0 Test accuracy: 0.9802
# 349 Train accuracy: 1.0 Test accuracy: 0.9804
# 350 Train accuracy: 1.0 Test accuracy: 0.9805
# 351 Train accuracy: 1.0 Test accuracy: 0.9805
# 352 Train accuracy: 1.0 Test accuracy: 0.9802
# 353 Train accuracy: 1.0 Test accuracy: 0.9804
# 354 Train accuracy: 1.0 Test accuracy: 0.9804
# 355 Train accuracy: 1.0 Test accuracy: 0.9803
# 356 Train accuracy: 1.0 Test accuracy: 0.9805
# 357 Train accuracy: 1.0 Test accuracy: 0.9804
# 358 Train accuracy: 1.0 Test accuracy: 0.9805
# 359 Train accuracy: 1.0 Test accuracy: 0.9804
# 360 Train accuracy: 1.0 Test accuracy: 0.9805
# 361 Train accuracy: 1.0 Test accuracy: 0.9805
# 362 Train accuracy: 1.0 Test accuracy: 0.9805
# 363 Train accuracy: 1.0 Test accuracy: 0.9805
# 364 Train accuracy: 1.0 Test accuracy: 0.9804
# 365 Train accuracy: 1.0 Test accuracy: 0.9802
# 366 Train accuracy: 1.0 Test accuracy: 0.9805
# 367 Train accuracy: 1.0 Test accuracy: 0.9804
# 368 Train accuracy: 1.0 Test accuracy: 0.9804
# 369 Train accuracy: 1.0 Test accuracy: 0.9805
# 370 Train accuracy: 1.0 Test accuracy: 0.9805
# 371 Train accuracy: 1.0 Test accuracy: 0.9805
# 372 Train accuracy: 1.0 Test accuracy: 0.9805
# 373 Train accuracy: 1.0 Test accuracy: 0.9805
# 374 Train accuracy: 1.0 Test accuracy: 0.9803
# 375 Train accuracy: 1.0 Test accuracy: 0.9804
# 376 Train accuracy: 1.0 Test accuracy: 0.9805
# 377 Train accuracy: 1.0 Test accuracy: 0.9803
# 378 Train accuracy: 1.0 Test accuracy: 0.9804
# 379 Train accuracy: 1.0 Test accuracy: 0.9805
# 380 Train accuracy: 1.0 Test accuracy: 0.9805
# 381 Train accuracy: 1.0 Test accuracy: 0.9804
# 382 Train accuracy: 1.0 Test accuracy: 0.9803
# 383 Train accuracy: 1.0 Test accuracy: 0.9803
# 384 Train accuracy: 1.0 Test accuracy: 0.9803
# 385 Train accuracy: 1.0 Test accuracy: 0.9805
# 386 Train accuracy: 1.0 Test accuracy: 0.9803
# 387 Train accuracy: 1.0 Test accuracy: 0.9805
# 388 Train accuracy: 1.0 Test accuracy: 0.9805
# 389 Train accuracy: 1.0 Test accuracy: 0.9804
# 390 Train accuracy: 1.0 Test accuracy: 0.9805
# 391 Train accuracy: 1.0 Test accuracy: 0.9803
# 392 Train accuracy: 1.0 Test accuracy: 0.9804
# 393 Train accuracy: 1.0 Test accuracy: 0.9804
# 394 Train accuracy: 1.0 Test accuracy: 0.9804
# 395 Train accuracy: 1.0 Test accuracy: 0.9803
# 396 Train accuracy: 1.0 Test accuracy: 0.9804
# 397 Train accuracy: 1.0 Test accuracy: 0.9806
# 398 Train accuracy: 1.0 Test accuracy: 0.9803
# 399 Train accuracy: 1.0 Test accuracy: 0.9803

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final.ckpt")
    X_new_scaled = [...] # some new images (scaled from 0 to 1)
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final.ckpt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b90ab7fa8ded> in <module>()
#       2     saver.restore(sess, "./my_model_final.ckpt")
#       3     X_new_scaled = [...] # some new images (scaled from 0 to 1)
# ----> 4     Z = logits.eval(feed_dict={X: X_new_scaled})
#       5     y_pred = np.argmax(Z, axis=1)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     711
#     712     """
# --> 713     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     714
#     715
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5155                        "the tensor's graph is different from the session's "
#    5156                        "graph.")
# -> 5157   return session.run(tensors, feed_dict)
#    5158
#    5159
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1119             feed_handles[subfeed_t] = subfeed_val
#    1120           else:
# -> 1121             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1122
#    1123           if (not is_tensor_handle_feed and
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# TypeError: float() argument must be a string or a number, not 'ellipsis'
